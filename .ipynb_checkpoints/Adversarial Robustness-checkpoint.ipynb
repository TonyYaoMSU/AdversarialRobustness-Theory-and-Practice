# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np


# at very beginning, you should bury your random seed number.

# first you need to load your data

# you define the batch size and decide whether you want shuffle them 

# Then you make your model network structure whether it is imported or made by your hand

# when you define your structure, you need to give your optimizer, like adam, SGD, blabla; you give the loss crossentropy, MSE or KLdivergence and many other Losses. 

# Finally, you give your iterations. for epoch in range(100): you zero_grad, backward, and step()

# Below is the whole code of implementation of MLP

torch.manual_seed(0)
model = nn.Sequential(nn.Linear(1,100), nn.ReLU(), 
                      nn.Linear(100,100), nn.ReLU(), 
                      nn.Linear(100,100), nn.ReLU(), 
                      nn.Linear(100,1))
opt = optim.SGD(model.parameters(),lr=1e-2)


for _ in range(100):
    loss = nn.MSELoss()( model(torch.randn(100,1))  , torch.randn(100,1))     #input is random numbers
    opt.zero_grad()
    loss.backward()
    opt.step() # performs a single optimization step!
                      
plt.plot(np.arange(-3,3,0.01), model(torch.arange(-3,3,0.01)[:,None]).detach().numpy())
plt.xlabel("Input")
plt.ylabel("Output")
# Out:
# Text(0, 0.5, 'Output')

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") 

class Flatten(nn.Module):
    def forward(self, x):
        return x.view(x.shape[0], -1) 
    
    # here x.shape[0] refers to the number of samples
    
    # start with a flatten function which stretches one dataset into one column

# initiated with a flatten 28*28 = 784 vector
    
model_dnn_2 = nn.Sequential(Flatten(), nn.Linear(784,200), nn.ReLU(), 
                            nn.Linear(200,10)).to(device)  

model_dnn_4 = nn.Sequential(Flatten(), nn.Linear(784,200), nn.ReLU(), 
                            nn.Linear(200,100), nn.ReLU(),
                            nn.Linear(100,100), nn.ReLU(),
                            nn.Linear(100,10)).to(device)

model_cnn = nn.Sequential(nn.Conv2d(1, 32, 3, padding=1), nn.ReLU(),   # again, 3 is the kernel size
                          nn.Conv2d(32, 32, 3, padding=1, stride=2), nn.ReLU(), # 3 is the kernel size
                          nn.Conv2d(32, 64, 3, padding=1), nn.ReLU(),  
                          nn.Conv2d(64, 64, 3, padding=1, stride=2), nn.ReLU(),
                          Flatten(),   # from conv to fc
                          # again from conv 2 linear, we need to calculate input size
                          nn.Linear(7*7*64, 100), nn.ReLU(),  # 7*7*64 
                          nn.Linear(100, 10)).to(device)

# %%
from torchvision import datasets, transforms # torchvision.transforms.Compose(transforms) 
                                             #Composes several transforms together.
from torch.utils.data import DataLoader

mnist_train = datasets.MNIST("../data", train=True, download=True, transform=transforms.ToTensor())# create train set
mnist_test = datasets.MNIST("../data", train=False, download=True, transform=transforms.ToTensor())# create test set
train_loader = DataLoader(mnist_train, batch_size = 100, shuffle=True)    # create mini batch with Shuffle
test_loader = DataLoader(mnist_test, batch_size = 100, shuffle=False)

# %%
def epoch(loader, model, opt=None):    # create epochs extracting minibatch loader, model and optimizer function
    total_loss, total_err = 0.,0.
    for X,y in loader:
        X,y = X.to(device), y.to(device)
        yp = model(X)
        loss = nn.CrossEntropyLoss()(yp,y)   # yp y_predict; y groundtruth
        if opt:                        # zero_grad()->backward()->step()
            opt.zero_grad()
            loss.backward()
            opt.step()
        
        total_err += (yp.max(dim=1)[1] != y).sum().item() 
        total_loss += loss.item() * X.shape[0]  # loss * batch size
    return total_err / len(loader.dataset), total_loss / len(loader.dataset)

# %%
opt = optim.SGD(model_dnn_2.parameters(), lr=1e-1)     # 
for _ in range(10):
    train_err, train_loss = epoch(train_loader, model_dnn_2, opt)
    test_err, test_loss = epoch(test_loader, model_dnn_2) # test no need grad
    print(*("{:.6f}".format(i) for i in (train_err, train_loss, test_err, test_loss)), sep="\t")
# Out:
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(10)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(9)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(9)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(9)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(9)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(10)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(9)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(10)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(13)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(9)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(9)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(10)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(9)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(11)
# torch.Size([100, 1, 28, 28])
# tensor(11)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(9)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(9)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(10)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(10)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(11)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(13)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# 0.041050	0.145320	0.043500	0.141817
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(8)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(10)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(0)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(9)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(5)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(7)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(1)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(6)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(2)
# torch.Size([100, 1, 28, 28])
# tensor(4)
# torch.Size([100, 1, 28, 28])
# tensor(3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-f7b4866d4c5d> in <module>
#       1 opt = optim.SGD(model_dnn_2.parameters(), lr=1e-1)
#       2 for _ in range(10):
# ----> 3     train_err, train_loss = epoch(train_loader, model_dnn_2, opt)
#       4     test_err, test_loss = epoch(test_loader, model_dnn_2)
#       5     print(*("{:.6f}".format(i) for i in (train_err, train_loss, test_err, test_loss)), sep="\t")
#
# <ipython-input-23-8c70f2d73ce1> in epoch(loader, model, opt)
#       1 def epoch(loader, model, opt=None):    # create epochs extracting minibatch loader, model and optimizer function
#       2     total_loss, total_err = 0.,0.
# ----> 3     for X,y in loader:
#       4         X,y = X.to(device), y.to(device)
#       5         yp = model(X)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     558         if self.num_workers == 0:  # same-process loading
#     559             indices = next(self.sample_iter)  # may raise StopIteration
# --> 560             batch = self.collate_fn([self.dataset[i] for i in indices])
#     561             if self.pin_memory:
#     562                 batch = _utils.pin_memory.pin_memory_batch(batch)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torchvision/datasets/mnist.py in __getitem__(self, index)
#      93
#      94         if self.transform is not None:
# ---> 95             img = self.transform(img)
#      96
#      97         if self.target_transform is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#      90             Tensor: Converted image.
#      91         """
# ---> 92         return F.to_tensor(pic)
#      93
#      94     def __repr__(self):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/torchvision/transforms/functional.py in to_tensor(pic)
#      97     img = img.transpose(0, 1).transpose(0, 2).contiguous()
#      98     if isinstance(img, torch.ByteTensor):
# ---> 99         return img.float().div(255)
#     100     else:
#     101         return img
#
# KeyboardInterrupt:

# %%
opt = optim.SGD(model_dnn_4.parameters(), lr=1e-1)
for _ in range(10):
    train_err, train_loss = epoch(train_loader, model_dnn_4, opt)
    test_err, test_loss = epoch(test_loader, model_dnn_4)
    print(*("{:.6f}".format(i) for i in (train_err, train_loss, test_err, test_loss)), sep="\t")

# %%
opt = optim.SGD(model_cnn.parameters(), lr=1e-1)
for t in range(10):
    train_err, train_loss = epoch(train_loader, model_cnn, opt)
    test_err, test_loss = epoch(test_loader, model_cnn)
    if t == 4:
        for param_group in opt.param_groups:
            param_group["lr"] = 1e-2
    print(*("{:.6f}".format(i) for i in (train_err, train_loss, test_err, test_loss)), sep="\t")

# %%
def fgsm(model, X,y, epsilon):
    """ Construct FGSM adversarial examples on the examples X"""
    delta = torch.zeros_like(X,requires_grad = True)
    loss = nn.CrossEntropyLoss()(model(X+delta),y)
    loss.backward()
    return epsilon*delta.grad.detach().sign() #return fgsm second term

# %%
for X,y in test_loader:
    X.y = X.to(device), y.to(device)
    break
    
def plot_images(X,y,yp,M,N):
    f,ax = plt.subplots(M,N, sharex=True, sharey=True, figsize=(N,M*1.3))
    for i in range(M):
        for j in range(N):
            ax[i][j].imshow(1-X[i*N+j][0].cpu().numpy(), cmap="gray")
            title = ax[i][j].set_title("Pred: {}".format(yp[i*N+j].max(dim=0)[1]))
            plt.setp(title, color=('g' if yp[i*N+j].max(dim=0)[1] == y[i*N+j] else 'r'))
            ax[i][j].set_axis_off()
    plt.tight_layout()

# %%
yp = model_dnn_2(X)
plot_images(X, y, yp, 3, 6

# %%
delta = fgsm(model_dnn_2, X, y, 0.1)
yp = model_dnn_2(X + delta)
plot_images(X+delta, y, yp, 3, 6)

# %%
delta = fgsm(model_cnn, X, y, 0.1)
yp = model_cnn(X + delta)
plot_images(X+delta, y, yp, 3, 6)

# %%
def epoch_adversarial(model, loader, attack, *args):
    total_loss, total_err = 0.,0.
    for X,y in loader:
        X,y = X.to(device), y.to(device)
        delta = attack(model, X, y, *args)
        yp = model(X+delta)
        loss = nn.CrossEntropyLoss()(yp,y)
        
        total_err += (yp.max(dim=1)[1] != y).sum().item()
        total_loss += loss.item() * X.shape[0]
    return total_err / len(loader.dataset), total_loss / len(loader.dataset)

# %%
print("2-layer DNN:", epoch_adversarial(model_dnn_2, test_loader, fgsm, 0.1)[0])
print("4-layer DNN:", epoch_adversarial(model_dnn_4, test_loader, fgsm, 0.1)[0])
print("        CNN:", epoch_adversarial(model_cnn, test_loader, fgsm, 0.1)[0])

# %%
def pgd(model, X, y, epsilon, alpha, num_iter):
    """ Construct FGSM adversarial examples on the examples X"""
    delta = torch.zeros_like(X, requires_grad=True)    # delta is the same size as X,start from zero
    for t in range(num_iter):
        loss = nn.CrossEntropyLoss()(model(X + delta), y)
        loss.backward()
        delta.data = (delta + X.shape[0]*alpha*delta.grad.data).clamp(-epsilon,epsilon) #why multiply shape[0] here
        delta.grad.zero_()
    return delta.detach()

# %%
### Illustrate attacked images

delta = pgd(model_cnn, X, y, 0.1, 1e4, 1000)
yp = model_cnn(X + delta)
plot_images(X+delta, y, yp, 3, 6)

# %%
# construct iterative FGSM with loss_infinity


def pgd_linf(model, X, y, epsilon, alpha, num_iter):
    """ Construct FGSM adversarial examples on the examples X"""
    delta = torch.zeros_like(X, requires_grad=True)
    for t in range(num_iter):
        loss = nn.CrossEntropyLoss()(model(X + delta), y)
        loss.backward()
        delta.data = (delta + alpha*delta.grad.detach().sign()).clamp(-epsilon,epsilon)
        delta.grad.zero_()
    return delta.detach()

# %%
### Illustrate attacked images
delta = pgd_linf(model_cnn, X, y, epsilon=0.1, alpha=1e-2, num_iter=40)
yp = model_cnn(X + delta)
plot_images(X+delta, y, yp, 3, 6)

# %%
print("2-layer DNN:", epoch_adversarial(model_dnn_2, test_loader, pgd_linf, 0.1, 1e-2, 40)[0])
print("4-layer DNN:", epoch_adversarial(model_dnn_4, test_loader, pgd_linf, 0.1, 1e-2, 40)[0])
print("CNN:", epoch_adversarial(model_cnn, test_loader, pgd_linf, 0.1, 1e-2, 40)[0])

# above replaces FGSM with 40step PGD

# %%
def pgd_linf_rand(model, X, y, epsilon, alpha, num_iter, restarts):
    """ Construct PGD adversarial examples on the samples X, with random restarts"""
    max_loss = torch.zeros(y.shape[0]).to(y.device)
    max_delta = torch.zeros_like(X)    
    # with different random restarts, we can get a max delta and loss here
    
    for i in range(restarts):
        delta = torch.rand_like(X, requires_grad=True)  # start from some random point
        
        # rand refers to [0,1) ->(2 * delta -1 ) [-1,1) -> (-e,+e)
        delta.data = delta.data * 2 * epsilon - epsilon  # epsilon* (2 * delta -1 ) this maps 
        
        for t in range(num_iter):
            loss = nn.CrossEntropyLoss()(model(X + delta), y)
            loss.backward()
            delta.data = (delta + alpha*delta.grad.detach().sign()).clamp(-epsilon,epsilon)
            delta.grad.zero_()
        
        all_loss = nn.CrossEntropyLoss(reduction='none')(model(X+delta),y)
        max_delta[all_loss >= max_loss] = delta.detach()[all_loss >= max_loss]
        max_loss = torch.max(max_loss, all_loss)
        
    return max_delta
print("CNN:", epoch_adversarial(model_cnn, test_loader, pgd_linf_rand, 0.1, 1e-2, 40, 10)[0])

# %%
def pgd_linf_targ(model, X, y, epsilon, alpha, num_iter, y_targ):
    """ Construct targeted adversarial examples on the examples X"""
    delta = torch.zeros_like(X, requires_grad=True)
    for t in range(num_iter):
        yp = model(X + delta)
        loss = (yp[:,y_targ] - yp.gather(1,y[:,None])[:,0]).sum()
        loss.backward()
        delta.data = (delta + alpha*delta.grad.detach().sign()).clamp(-epsilon,epsilon)
        delta.grad.zero_()
    return delta.detach()  #instead of finding some unknown max adv. for x*, we find how to fool classifier we are target 0!
delta = pgd_linf_targ(model_cnn, X, y, epsilon=0.2, alpha=1e-2, num_iter=40, y_targ=0)
yp = model_cnn(X + delta)
plot_images(X+delta, y, yp, 3, 6)

# %%
def pgd_linf_targ2(model, X, y, epsilon, alpha, num_iter, y_targ):
    """ Construct targeted adversarial examples on the examples X"""
    delta = torch.zeros_like(X, requires_grad=True)
    for t in range(num_iter):
        yp = model(X + delta)
        loss = 2*yp[:,y_targ].sum() - yp.sum()
        loss.backward()
        delta.data = (delta + alpha*delta.grad.detach().sign()).clamp(-epsilon,epsilon)
        delta.grad.zero_()
    return delta.detach()

delta = pgd_linf_targ(model_cnn, X, y, epsilon=0.2, alpha=1e-2, num_iter=40, y_targ=0)
yp = model_cnn(X + delta)
plot_images(X+delta, y, yp, 3, 6)

# %%
# we will continue here non-loss-infinity norms later after my interview with Dr. Liu (Sijia) in MSU

# %%
# later about combinatorial optimization 组合优化问题 including bound propogation

# %%
# Certification for robustness check whether they are robust

# %%
# convex relaxation

# %%
# Chapter 4 starts!

# %% [markdown]
# # KEY IDEA
#
# ## our key idea is as: 1. select minibatch B, initialize gradient vector g:= 0; 2. For each (x,y) in B: a. Find an attack perturbation delta* by (approximately) optimizing b. add gradient to delta* 3. update theta with gradient descent g

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

mnist_train = datasets.MNIST("../data", train=True, download=True, transform=transforms.ToTensor())
mnist_test = datasets.MNIST("../data", train=False, download=True, transform=transforms.ToTensor())
train_loader = DataLoader(mnist_train, batch_size = 100, shuffle=True)
test_loader = DataLoader(mnist_test, batch_size = 100, shuffle=False)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
torch.manual_seed(0)

class Flatten(nn.Module):
    def forward(self, x):
        return x.view(x.shape[0], -1)    

model_cnn = nn.Sequential(nn.Conv2d(1, 32, 3, padding=1), nn.ReLU(),
                          nn.Conv2d(32, 32, 3, padding=1, stride=2), nn.ReLU(),
                          nn.Conv2d(32, 64, 3, padding=1), nn.ReLU(),
                          nn.Conv2d(64, 64, 3, padding=1, stride=2), nn.ReLU(),
                          Flatten(),
                          nn.Linear(7*7*64, 100), nn.ReLU(),
                          nn.Linear(100, 10)).to(device)

# %%
def fgsm(model, X, y, epsilon=0.1):
    """ Construct FGSM adversarial examples on the examples X"""
    delta = torch.zeros_like(X, requires_grad=True)
    loss = nn.CrossEntropyLoss()(model(X + delta), y)
    loss.backward()
    return epsilon * delta.grad.detach().sign()

def pgd_linf(model, X, y, epsilon=0.1, alpha=0.01, num_iter=20, randomize=False):
    """ Construct FGSM adversarial examples on the examples X"""
    if randomize:
        delta = torch.rand_like(X, requires_grad=True)
        delta.data = delta.data * 2 * epsilon - epsilon
    else:
        delta = torch.zeros_like(X, requires_grad=True)
        
    for t in range(num_iter):
        loss = nn.CrossEntropyLoss()(model(X + delta), y)
        loss.backward()
        delta.data = (delta + alpha*delta.grad.detach().sign()).clamp(-epsilon,epsilon)
        delta.grad.zero_()
    return delta.detach()

# %%
def epoch(loader, model, opt=None):
    """Standard training/evaluation epoch over the dataset"""
    total_loss, total_err = 0.,0.
    for X,y in loader:
        X,y = X.to(device), y.to(device)
        yp = model(X)
        loss = nn.CrossEntropyLoss()(yp,y)
        if opt:
            opt.zero_grad()
            loss.backward()
            opt.step()
        
        total_err += (yp.max(dim=1)[1] != y).sum().item()
        total_loss += loss.item() * X.shape[0]
    return total_err / len(loader.dataset), total_loss / len(loader.dataset)

def epoch_adversarial(loader, model, attack, opt=None, **kwargs):
    """Adversarial training/evaluation epoch over the dataset"""
    total_loss, total_err = 0.,0.
    for X,y in loader:
        X,y = X.to(device), y.to(device)
        delta = attack(model, X, y, **kwargs)
        yp = model(X+delta)
        loss = nn.CrossEntropyLoss()(yp,y)
        if opt:
            opt.zero_grad()
            loss.backward()
            opt.step()
        
        total_err += (yp.max(dim=1)[1] != y).sum().item()
        total_loss += loss.item() * X.shape[0]
    return total_err / len(loader.dataset), total_loss / len(loader.dataset)

# %%
opt = optim.SGD(model_cnn.parameters(), lr=1e-1)
for t in range(10):
    train_err, train_loss = epoch(train_loader, model_cnn, opt)
    test_err, test_loss = epoch(test_loader, model_cnn)
    adv_err, adv_loss = epoch_adversarial(test_loader, model_cnn, pgd_linf)
    if t == 4:
        for param_group in opt.param_groups:
            param_group["lr"] = 1e-2
    print(*("{:.6f}".format(i) for i in (train_err, test_err, adv_err)), sep="\t")
torch.save(model_cnn.state_dict(), "model_cnn.pt")

# %%
model_cnn_robust = nn.Sequential(nn.Conv2d(1, 32, 3, padding=1), nn.ReLU(),
                                 nn.Conv2d(32, 32, 3, padding=1, stride=2), nn.ReLU(),
                                 nn.Conv2d(32, 64, 3, padding=1), nn.ReLU(),
                                 nn.Conv2d(64, 64, 3, padding=1, stride=2), nn.ReLU(),
                                 Flatten(),
                                 nn.Linear(7*7*64, 100), nn.ReLU(),
                                 nn.Linear(100, 10)).to(device)

# %%
opt = optim.SGD(model_cnn_robust.parameters(), lr=1e-1)
for t in range(10):
    train_err, train_loss = epoch_adversarial(train_loader, model_cnn_robust, pgd_linf, opt)
    test_err, test_loss = epoch(test_loader, model_cnn_robust)
    adv_err, adv_loss = epoch_adversarial(test_loader, model_cnn_robust, pgd_linf)
    if t == 4:
        for param_group in opt.param_groups:
            param_group["lr"] = 1e-2
    print(*("{:.6f}".format(i) for i in (train_err, test_err, adv_err)), sep="\t")
torch.save(model_cnn_robust.state_dict(), "model_cnn_robust.pt")

# %%
for X,y in test_loader:
    X,y = X.to(device), y.to(device)
    break

# %%
def draw_loss(model, X, epsilon):   # keep it here for Tony to understand dir1
    Xi, Yi = np.meshgrid(np.linspace(-epsilon, epsilon,100), np.linspace(-epsilon,epsilon,100))
    
    def grad_at_delta(delta):
        delta.requires_grad_(True)
        nn.CrossEntropyLoss()(model(X+delta), y[0:1]).backward()
        return delta.grad.detach().sign().view(-1).cpu().numpy()   # smooth

    dir1 = grad_at_delta(torch.zeros_like(X, requires_grad=True))
    delta2 = torch.zeros_like(X, requires_grad=True)
    delta2.data = torch.tensor(dir1).view_as(X).to(device)
    dir2 = grad_at_delta(delta2)
    np.random.seed(0)
    dir2 = np.sign(np.random.randn(dir1.shape[0]))
    
    all_deltas = torch.tensor((np.array([Xi.flatten(), Yi.flatten()]).T @ 
                              np.array([dir2, dir1])).astype(np.float32)).to(device)
    yp = model(all_deltas.view(-1,1,28,28) + X)
    Zi = nn.CrossEntropyLoss(reduction="none")(yp, y[0:1].repeat(yp.shape[0])).detach().cpu().numpy()
    Zi = Zi.reshape(*Xi.shape)
    #Zi = (Zi-Zi.min())/(Zi.max() - Zi.min())
    
    fig = plt.figure(figsize=(10,10))
    ax = fig.gca(projection='3d')
    ls = LightSource(azdeg=0, altdeg=200)
    rgb = ls.shade(Zi, plt.cm.coolwarm)

    surf = ax.plot_surface(Xi, Yi, Zi, rstride=1, cstride=1, linewidth=0,
                       antialiased=True, facecolors=rgb)

    
draw_loss(model_cnn, X[0:1], 0.1)
draw_loss(model_cnn_robust, X[0:1], 0.1)

# %%
# we left relaxation-based robust training and Cifar. Wait Tony!
